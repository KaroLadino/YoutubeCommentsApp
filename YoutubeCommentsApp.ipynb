# %%
# !pip install --upgrade google-api-python-client
# !pip install google-auth google-auth-oauthlib google-auth-httplib2
# !pip install --upgrade oauth2client
# Out:
# Requirement already up-to-date: google-api-python-client in c:\users\ladin\anaconda3\lib\site-packages (1.7.11)
# Requirement already satisfied, skipping upgrade: google-auth>=1.4.1 in c:\users\ladin\anaconda3\lib\site-packages (from google-api-python-client) (1.6.3)
# Requirement already satisfied, skipping upgrade: six<2dev,>=1.6.1 in c:\users\ladin\anaconda3\lib\site-packages (from google-api-python-client) (1.12.0)
# Requirement already satisfied, skipping upgrade: uritemplate<4dev,>=3.0.0 in c:\users\ladin\anaconda3\lib\site-packages (from google-api-python-client) (3.0.0)
# Requirement already satisfied, skipping upgrade: google-auth-httplib2>=0.0.3 in c:\users\ladin\anaconda3\lib\site-packages (from google-api-python-client) (0.0.3)
# Requirement already satisfied, skipping upgrade: httplib2<1dev,>=0.9.2 in c:\users\ladin\anaconda3\lib\site-packages (from google-api-python-client) (0.13.1)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in c:\users\ladin\anaconda3\lib\site-packages (from google-auth>=1.4.1->google-api-python-client) (0.2.6)
# Requirement already satisfied, skipping upgrade: rsa>=3.1.4 in c:\users\ladin\anaconda3\lib\site-packages (from google-auth>=1.4.1->google-api-python-client) (4.0)
# Requirement already satisfied, skipping upgrade: cachetools>=2.0.0 in c:\users\ladin\anaconda3\lib\site-packages (from google-auth>=1.4.1->google-api-python-client) (3.1.1)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in c:\users\ladin\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->google-api-python-client) (0.4.6)

# %%
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
from youtube_data import youtube_search

# %%
test = youtube_search("Grupo Niche")
test.keys()
# Out:
# dict_keys(['tags', 'channelId', 'channelTitle', 'categoryId', 'title', 'videoId', 'viewCount', 'likeCount', 'dislikeCount', 'commentCount', 'favoriteCount'])

# %%
test['commentCount'][:5]
# Out:
# ['13935', '1645', '8145', '1162', '594']

# %%
df = pd.DataFrame(data=test)
df.head()
# Out:
#                                                 tags  \
# 0                                                 []
# 1  [Juan, gabriel, aventura, Salsa mix, salsa dan...
# 2                              [Grupo, Niche, Salsa]
# 3                                            [Video]
# 4          [Grupo Niche, The Best, Busca Por Dentro]
#
#                   channelId                 channelTitle categoryId  \
# 0  UChwYUhSbCXLd2d2P73cWX0A  viejoteca tropical bailable         10
# 1  UCf8Pbsw8fG4BdePN1R2KhmQ                  Grupo Niche         22
# 2  UCG50pH-VK6HO3uIEujpp0fA                     Chinofeo         10
# 3  UC4FjjpgmkCsvdjysJ0K7rog                 Picoso Music          1
# 4  UCSIv6hggVq084OBlUDIjkzQ          Grupo Niche - Topic         10
#
#                                                title      videoId  viewCount  \
# 0                      SIN SENTIMIENTO - GRUPO NICHE  j42jEMFdynY  262420851
# 1  Grupo Niche - &quot;Una Aventura&quot; (Video ...  UwnmzIgNzyU   22453281
# 2                        Grupo Niche Gotas De Lluvia  MjXU7I6aBpA  118906766
# 3               Nuestro sueño - Grupo niche (letra)  gxAp9fKUPSs   34956761
# 4                                   Busca Por Dentro  IVluKJqdEfE   12634214
#
#   likeCount dislikeCount commentCount favoriteCount
# 0    426420        45653        13935             0
# 1     48175         4363         1645             0
# 2    211044        20280         8145             0
# 3     95931         5130         1162             0
# 4     27930         2300          594             0

# %%
df1 = df[['title','viewCount','channelTitle','commentCount','likeCount','dislikeCount','tags','favoriteCount','videoId','channelId','categoryId']]
df1.columns = ['Title','viewCount','channelTitle','commentCount','likeCount','dislikeCount','tags','favoriteCount','videoId','channelId','categoryId']
df1.head()
# Out:
#                                                Title  viewCount  \
# 0                      SIN SENTIMIENTO - GRUPO NICHE  262420851
# 1  Grupo Niche - &quot;Una Aventura&quot; (Video ...   22453281
# 2                        Grupo Niche Gotas De Lluvia  118906766
# 3               Nuestro sueño - Grupo niche (letra)   34956761
# 4                                   Busca Por Dentro   12634214
#
#                   channelTitle commentCount likeCount dislikeCount  \
# 0  viejoteca tropical bailable        13935    426420        45653
# 1                  Grupo Niche         1645     48175         4363
# 2                     Chinofeo         8145    211044        20280
# 3                 Picoso Music         1162     95931         5130
# 4          Grupo Niche - Topic          594     27930         2300
#
#                                                 tags favoriteCount  \
# 0                                                 []             0
# 1  [Juan, gabriel, aventura, Salsa mix, salsa dan...             0
# 2                              [Grupo, Niche, Salsa]             0
# 3                                            [Video]             0
# 4          [Grupo Niche, The Best, Busca Por Dentro]             0
#
#        videoId                 channelId categoryId
# 0  j42jEMFdynY  UChwYUhSbCXLd2d2P73cWX0A         10
# 1  UwnmzIgNzyU  UCf8Pbsw8fG4BdePN1R2KhmQ         22
# 2  MjXU7I6aBpA  UCG50pH-VK6HO3uIEujpp0fA         10
# 3  gxAp9fKUPSs  UC4FjjpgmkCsvdjysJ0K7rog          1
# 4  IVluKJqdEfE  UCSIv6hggVq084OBlUDIjkzQ         10

# %%
import numpy as np
numeric_dtype = ['viewCount','commentCount','likeCount','dislikeCount','favoriteCount']
for i in numeric_dtype:
    df1[i] = df[i].astype(int)

GrupoNiche = df1[df1['channelTitle']=='Grupo Niche']
GrupoNiche.head()
# Out:
#                                                 Title  viewCount channelTitle  \
# 1   Grupo Niche - &quot;Una Aventura&quot; (Video ...   22453281  Grupo Niche
# 8         Grupo Niche - Cosas Bonitas (Video Oficial)     993444  Grupo Niche
# 24  Grupo Niche - &quot;Duele Mas&quot; (Video Ori...     520846  Grupo Niche
# 28                         Grupo Niche - Mucho sabor!       4441  Grupo Niche
# 41  Grupo Niche - &quot;La Magia de Tus Besos&quot...    6476880  Grupo Niche
#
#     commentCount  likeCount  dislikeCount  \
# 1           1645      48175          4363
# 8            961      17234           595
# 24            59       1798           139
# 28            12        150             3
# 41           575      26613          1560
#
#                                                  tags  favoriteCount  \
# 1   [Juan, gabriel, aventura, Salsa mix, salsa dan...              0
# 8   [Salsa, Grupo Niche, Jairo Varela, Cali Pachan...              0
# 24  [Niche, Duele, Mas, Grupo, niche, grupo niche,...              0
# 28                                                 []              0
# 41  [colombia, musica, latina, hector, lavoe, fani...              0
#
#         videoId                 channelId categoryId
# 1   UwnmzIgNzyU  UCf8Pbsw8fG4BdePN1R2KhmQ         22
# 8   6gj6w6sJxpk  UCf8Pbsw8fG4BdePN1R2KhmQ         10
# 24  Lb1Ad1g8iXg  UCf8Pbsw8fG4BdePN1R2KhmQ         22
# 28  XejR9Pz5-oU  UCf8Pbsw8fG4BdePN1R2KhmQ         10
# 41  db9O7lthBT0  UCf8Pbsw8fG4BdePN1R2KhmQ         10

# %%
GrupoNiche = GrupoNiche.sort_values(ascending=False,by='viewCount')
plt.bar(range(GrupoNiche.shape[0]),GrupoNiche['viewCount'])
plt.xticks(range(GrupoNiche.shape[0]),GrupoNiche['Title'],rotation=90)
plt.ylabel('viewCount in 100 millions')

plt.show()
