# %%
# !pip install --upgrade google-api-python-client
# !pip install google-auth google-auth-oauthlib google-auth-httplib2
# !pip install --upgrade oauth2client
# Out:
# Requirement already up-to-date: google-api-python-client in c:\users\ladin\anaconda3\lib\site-packages (1.7.11)
# Requirement already satisfied, skipping upgrade: google-auth>=1.4.1 in c:\users\ladin\anaconda3\lib\site-packages (from google-api-python-client) (1.6.3)
# Requirement already satisfied, skipping upgrade: six<2dev,>=1.6.1 in c:\users\ladin\anaconda3\lib\site-packages (from google-api-python-client) (1.12.0)
# Requirement already satisfied, skipping upgrade: uritemplate<4dev,>=3.0.0 in c:\users\ladin\anaconda3\lib\site-packages (from google-api-python-client) (3.0.0)
# Requirement already satisfied, skipping upgrade: google-auth-httplib2>=0.0.3 in c:\users\ladin\anaconda3\lib\site-packages (from google-api-python-client) (0.0.3)
# Requirement already satisfied, skipping upgrade: httplib2<1dev,>=0.9.2 in c:\users\ladin\anaconda3\lib\site-packages (from google-api-python-client) (0.13.1)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in c:\users\ladin\anaconda3\lib\site-packages (from google-auth>=1.4.1->google-api-python-client) (0.2.6)
# Requirement already satisfied, skipping upgrade: rsa>=3.1.4 in c:\users\ladin\anaconda3\lib\site-packages (from google-auth>=1.4.1->google-api-python-client) (4.0)
# Requirement already satisfied, skipping upgrade: cachetools>=2.0.0 in c:\users\ladin\anaconda3\lib\site-packages (from google-auth>=1.4.1->google-api-python-client) (3.1.1)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in c:\users\ladin\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->google-api-python-client) (0.4.6)

# %%
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
from youtube_data import youtube_search

# %%
test = youtube_search("Esgrima AEEA")
test.keys()
# Out:
# dict_keys(['tags', 'channelId', 'channelTitle', 'categoryId', 'title', 'videoId', 'viewCount', 'likeCount', 'dislikeCount', 'commentCount', 'favoriteCount'])

# %%
test['commentCount'][:5]
# Out:
# ['1', '0', '0', '9', '19']

# %%
df = pd.DataFrame(data=test)
df.head()
# Out:
#                                                 tags  \
# 0  [Espada, esgrima, VerdaderaDestreza, Destreza,...
# 1  [Espada, sable, saber, fencing, HEMA, Destreza...
# 2  [Espada, Esgrima, Rapier, Ropera, Verdadera De...
# 3  [Alberto Bomprezzi, Espada ropera, Spanish Rap...
# 4                           [Ropera, daga, destreza]
#
#                   channelId       channelTitle categoryId  \
# 0  UCHEvXeg8NmhsxcvoT07x-Xg       Esgrima AEEA         17
# 1  UCHEvXeg8NmhsxcvoT07x-Xg       Esgrima AEEA         17
# 2  UCHEvXeg8NmhsxcvoT07x-Xg       Esgrima AEEA         17
# 3  UCQri0iqK1GkXb6u4J1rtVpQ  Alberto Bomprezzi         17
# 4  UCSpDvHOKap2r_MTDnBAig7A          ElDavid66         17
#
#                                                title      videoId viewCount  \
# 0  Escuela de Esgrima Histórica de Madrid | Asalt...  PjGOPA94wIA       140
# 1  Escuela de Esgrima Histórica de Madrid | Asalt...  tBbcYVSNFSo       227
# 2                           Final Torneo Ropera 2018  ErXH3upVxyA       277
# 3            AEEA Spanish Rapier: Verdadera Destreza  -F3ipojwGrk     22312
# 4                           Combate de Ropera y Daga  QBK6l53Himc     18186
#
#   likeCount dislikeCount commentCount favoriteCount
# 0         9            0            1             0
# 1         6            0            0             0
# 2         7            0            0             0
# 3        50            7            9             0
# 4        75            2           19             0

# %%
df1 = df[['title','viewCount','channelTitle','commentCount','likeCount','dislikeCount','tags','favoriteCount','videoId','channelId','categoryId']]
df1.columns = ['Title','viewCount','channelTitle','commentCount','likeCount','dislikeCount','tags','favoriteCount','videoId','channelId','categoryId']
df1.head()
# Out:
#                                                Title viewCount  \
# 0  Escuela de Esgrima Histórica de Madrid | Asalt...       140
# 1  Escuela de Esgrima Histórica de Madrid | Asalt...       227
# 2                           Final Torneo Ropera 2018       277
# 3            AEEA Spanish Rapier: Verdadera Destreza     22312
# 4                           Combate de Ropera y Daga     18186
#
#         channelTitle commentCount likeCount dislikeCount  \
# 0       Esgrima AEEA            1         9            0
# 1       Esgrima AEEA            0         6            0
# 2       Esgrima AEEA            0         7            0
# 3  Alberto Bomprezzi            9        50            7
# 4          ElDavid66           19        75            2
#
#                                                 tags favoriteCount  \
# 0  [Espada, esgrima, VerdaderaDestreza, Destreza,...             0
# 1  [Espada, sable, saber, fencing, HEMA, Destreza...             0
# 2  [Espada, Esgrima, Rapier, Ropera, Verdadera De...             0
# 3  [Alberto Bomprezzi, Espada ropera, Spanish Rap...             0
# 4                           [Ropera, daga, destreza]             0
#
#        videoId                 channelId categoryId
# 0  PjGOPA94wIA  UCHEvXeg8NmhsxcvoT07x-Xg         17
# 1  tBbcYVSNFSo  UCHEvXeg8NmhsxcvoT07x-Xg         17
# 2  ErXH3upVxyA  UCHEvXeg8NmhsxcvoT07x-Xg         17
# 3  -F3ipojwGrk  UCQri0iqK1GkXb6u4J1rtVpQ         17
# 4  QBK6l53Himc  UCSpDvHOKap2r_MTDnBAig7A         17

# %%
import numpy as np
numeric_dtype = ['viewCount','commentCount','likeCount','dislikeCount','favoriteCount']
for i in numeric_dtype:
    df1[i] = df[i].astype(int)

EsgrimaAEEA = df1[df1['channelTitle']=='Esgrima AEEA']
EsgrimaAEEA.head()
# Out:
#                                                Title  viewCount  channelTitle  \
# 0  Escuela de Esgrima Histórica de Madrid | Asalt...        140  Esgrima AEEA
# 1  Escuela de Esgrima Histórica de Madrid | Asalt...        227  Esgrima AEEA
# 2                           Final Torneo Ropera 2018        277  Esgrima AEEA
# 8             Asalto de Espada Ropera Diciembre 2018        228  Esgrima AEEA
# 9                     Ejercicios de clase Junio 2017        107  Esgrima AEEA
#
#    commentCount  likeCount  dislikeCount  \
# 0             1          9             0
# 1             0          6             0
# 2             0          7             0
# 8             1          9             0
# 9             0          9             0
#
#                                                 tags  favoriteCount  \
# 0  [Espada, esgrima, VerdaderaDestreza, Destreza,...              0
# 1  [Espada, sable, saber, fencing, HEMA, Destreza...              0
# 2  [Espada, Esgrima, Rapier, Ropera, Verdadera De...              0
# 8  [Espada, esgrima, fencing, Sword, Destreza, HE...              0
# 9  [espada, ropera, esgrima, fencing, HEMA, destr...              0
#
#        videoId                 channelId categoryId
# 0  PjGOPA94wIA  UCHEvXeg8NmhsxcvoT07x-Xg         17
# 1  tBbcYVSNFSo  UCHEvXeg8NmhsxcvoT07x-Xg         17
# 2  ErXH3upVxyA  UCHEvXeg8NmhsxcvoT07x-Xg         17
# 8  VD1keRhBlvw  UCHEvXeg8NmhsxcvoT07x-Xg         17
# 9  EDIgpyUp5wI  UCHEvXeg8NmhsxcvoT07x-Xg         17

# %%
EsgrimaAEEA = EsgrimaAEEA.sort_values(ascending=False,by='viewCount')
plt.bar(range(EsgrimaAEEA.shape[0]),EsgrimaAEEA['viewCount'])
plt.xticks(range(EsgrimaAEEA.shape[0]),EsgrimaAEEA['Title'],rotation=90)
plt.ylabel('viewCount in 100 millions')

plt.show()
